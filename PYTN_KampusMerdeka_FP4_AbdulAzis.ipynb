# %% [markdown]
# ## 1. Introduce

# %% [markdown]
# ## 2. Import library

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler, normalize
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from scipy.cluster.hierarchy import dendrogram, linkage

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics
from sklearn.metrics import accuracy_score,f1_score, precision_score, recall_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# Supaya pesan warning tidak muncul,maka diignore
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## 3. Data Loading

# %%
# membaca dataset
df_cc = pd.read_csv('C:/Users/HP/OneDrive/Documents/Kampus Merdeka/Study Independen/Final Project 4/CC GENERAL.csv')

# %%
pd.set_option("display.max_columns", None)

# %%
# melihat data 5 baris teratas
df_cc.head()
# Out:
#   CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  C10001    40.900749           0.818182      95.40              0.00
# 1  C10002  3202.467416           0.909091       0.00              0.00
# 2  C10003  2495.148862           1.000000     773.17            773.17
# 3  C10004  1666.670542           0.636364    1499.00           1499.00
# 4  C10005   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# 1                    0.000000                          0.000000
# 2                    1.000000                          0.000000
# 3                    0.083333                          0.000000
# 4                    0.083333                          0.000000
#
#    CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 0                0.000000                 0              2        1000.0
# 1                0.250000                 4              0        7000.0
# 2                0.000000                 0             12        7500.0
# 3                0.083333                 1              1        7500.0
# 4                0.000000                 0              1        1200.0
#
#       PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE
# 0   201.802084        139.509787          0.000000      12
# 1  4103.032597       1072.340217          0.222222      12
# 2   622.066742        627.284787          0.000000      12
# 3     0.000000               NaN          0.000000      12
# 4   678.334763        244.791237          0.000000      12

# %%
# mengecek jumlah baris dan kolom pada data
df_cc.shape
# Out:
# (8950, 18)

# %%
# mengecek tipe data
df_cc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8950 entries, 0 to 8949
# Data columns (total 18 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   CUST_ID                           8950 non-null   object
#  1   BALANCE                           8950 non-null   float64
#  2   BALANCE_FREQUENCY                 8950 non-null   float64
#  3   PURCHASES                         8950 non-null   float64
#  4   ONEOFF_PURCHASES                  8950 non-null   float64
#  5   INSTALLMENTS_PURCHASES            8950 non-null   float64
#  6   CASH_ADVANCE                      8950 non-null   float64
#  7   PURCHASES_FREQUENCY               8950 non-null   float64
#  8   ONEOFF_PURCHASES_FREQUENCY        8950 non-null   float64
#  9   PURCHASES_INSTALLMENTS_FREQUENCY  8950 non-null   float64
#  10  CASH_ADVANCE_FREQUENCY            8950 non-null   float64
#  11  CASH_ADVANCE_TRX                  8950 non-null   int64
#  12  PURCHASES_TRX                     8950 non-null   int64
#  13  CREDIT_LIMIT                      8949 non-null   float64
#  14  PAYMENTS                          8950 non-null   float64
#  15  MINIMUM_PAYMENTS                  8637 non-null   float64
#  16  PRC_FULL_PAYMENT                  8950 non-null   float64
#  17  TENURE                            8950 non-null   int64
# dtypes: float64(14), int64(3), object(1)
# memory usage: 1.2+ MB

# %%
df_cc.columns
# Out:
# Index(['CUST_ID', 'BALANCE', 'BALANCE_FREQUENCY', 'PURCHASES',
#        'ONEOFF_PURCHASES', 'INSTALLMENTS_PURCHASES', 'CASH_ADVANCE',
#        'PURCHASES_FREQUENCY', 'ONEOFF_PURCHASES_FREQUENCY',
#        'PURCHASES_INSTALLMENTS_FREQUENCY', 'CASH_ADVANCE_FREQUENCY',
#        'CASH_ADVANCE_TRX', 'PURCHASES_TRX', 'CREDIT_LIMIT', 'PAYMENTS',
#        'MINIMUM_PAYMENTS', 'PRC_FULL_PAYMENT', 'TENURE'],
#       dtype='object')

# %%
df_cc.describe()
# Out:
#             BALANCE  BALANCE_FREQUENCY     PURCHASES  ONEOFF_PURCHASES  \
# count   8950.000000        8950.000000   8950.000000       8950.000000
# mean    1564.474828           0.877271   1003.204834        592.437371
# std     2081.531879           0.236904   2136.634782       1659.887917
# min        0.000000           0.000000      0.000000          0.000000
# 25%      128.281915           0.888889     39.635000          0.000000
# 50%      873.385231           1.000000    361.280000         38.000000
# 75%     2054.140036           1.000000   1110.130000        577.405000
# max    19043.138560           1.000000  49039.570000      40761.250000
#
#        INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# count             8950.000000   8950.000000          8950.000000
# mean               411.067645    978.871112             0.490351
# std                904.338115   2097.163877             0.401371
# min                  0.000000      0.000000             0.000000
# 25%                  0.000000      0.000000             0.083333
# 50%                 89.000000      0.000000             0.500000
# 75%                468.637500   1113.821139             0.916667
# max              22500.000000  47137.211760             1.000000
#
#        ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# count                 8950.000000                       8950.000000
# mean                     0.202458                          0.364437
# std                      0.298336                          0.397448
# min                      0.000000                          0.000000
# 25%                      0.000000                          0.000000
# 50%                      0.083333                          0.166667
# 75%                      0.300000                          0.750000
# max                      1.000000                          1.000000
#
#        CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# count             8950.000000       8950.000000    8950.000000   8949.000000
# mean                 0.135144          3.248827      14.709832   4494.449450
# std                  0.200121          6.824647      24.857649   3638.815725
# min                  0.000000          0.000000       0.000000     50.000000
# 25%                  0.000000          0.000000       1.000000   1600.000000
# 50%                  0.000000          0.000000       7.000000   3000.000000
# 75%                  0.222222          4.000000      17.000000   6500.000000
# max                  1.500000        123.000000     358.000000  30000.000000
#
#            PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT       TENURE
# count   8950.000000       8637.000000       8950.000000  8950.000000
# mean    1733.143852        864.206542          0.153715    11.517318
# std     2895.063757       2372.446607          0.292499     1.338331
# min        0.000000          0.019163          0.000000     6.000000
# 25%      383.276166        169.123707          0.000000    12.000000
# 50%      856.901546        312.343947          0.000000    12.000000
# 75%     1901.134317        825.485459          0.142857    12.000000
# max    50721.483360      76406.207520          1.000000    12.000000

# %% [markdown]
# ## 4. Data Cleaning

# %%
# melihat jumlah data yang memiliki duplikat
df_cc.duplicated().sum()
# Out:
# 0

# %%
# melihat jumalah nilai missing value
df_cc.isnull().sum()
# Out:
# CUST_ID                               0
# BALANCE                               0
# BALANCE_FREQUENCY                     0
# PURCHASES                             0
# ONEOFF_PURCHASES                      0
# INSTALLMENTS_PURCHASES                0
# CASH_ADVANCE                          0
# PURCHASES_FREQUENCY                   0
# ONEOFF_PURCHASES_FREQUENCY            0
# PURCHASES_INSTALLMENTS_FREQUENCY      0
# CASH_ADVANCE_FREQUENCY                0
# CASH_ADVANCE_TRX                      0
# PURCHASES_TRX                         0
# CREDIT_LIMIT                          1
# PAYMENTS                              0
# MINIMUM_PAYMENTS                    313
# PRC_FULL_PAYMENT                      0
# TENURE                                0
# dtype: int64

# %%
# mengisi missing value pada kolom minimum payments dan credit limit dengan median
df_cc['MINIMUM_PAYMENTS'].fillna(df_cc['MINIMUM_PAYMENTS'].median(),inplace=True)
df_cc['CREDIT_LIMIT'].fillna(df_cc['CREDIT_LIMIT'].median(),inplace=True)
df_cc.head()
# Out:
#   CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  C10001    40.900749           0.818182      95.40              0.00
# 1  C10002  3202.467416           0.909091       0.00              0.00
# 2  C10003  2495.148862           1.000000     773.17            773.17
# 3  C10004  1666.670542           0.636364    1499.00           1499.00
# 4  C10005   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# 1                    0.000000                          0.000000
# 2                    1.000000                          0.000000
# 3                    0.083333                          0.000000
# 4                    0.083333                          0.000000
#
#    CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 0                0.000000                 0              2        1000.0
# 1                0.250000                 4              0        7000.0
# 2                0.000000                 0             12        7500.0
# 3                0.083333                 1              1        7500.0
# 4                0.000000                 0              1        1200.0
#
#       PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE
# 0   201.802084        139.509787          0.000000      12
# 1  4103.032597       1072.340217          0.222222      12
# 2   622.066742        627.284787          0.000000      12
# 3     0.000000        312.343947          0.000000      12
# 4   678.334763        244.791237          0.000000      12

# %%
# menghapus kolom cust_id karena tidak diperlukan
df_cc = df_cc.drop('CUST_ID', axis=1)
df_cc.head()
# Out:
#        BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0    40.900749           0.818182      95.40              0.00
# 1  3202.467416           0.909091       0.00              0.00
# 2  2495.148862           1.000000     773.17            773.17
# 3  1666.670542           0.636364    1499.00           1499.00
# 4   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# 1                    0.000000                          0.000000
# 2                    1.000000                          0.000000
# 3                    0.083333                          0.000000
# 4                    0.083333                          0.000000
#
#    CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 0                0.000000                 0              2        1000.0
# 1                0.250000                 4              0        7000.0
# 2                0.000000                 0             12        7500.0
# 3                0.083333                 1              1        7500.0
# 4                0.000000                 0              1        1200.0
#
#       PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE
# 0   201.802084        139.509787          0.000000      12
# 1  4103.032597       1072.340217          0.222222      12
# 2   622.066742        627.284787          0.000000      12
# 3     0.000000        312.343947          0.000000      12
# 4   678.334763        244.791237          0.000000      12

# %%
# merubah nama pada setiap kolom
df_cc = df_cc.rename(columns={'BALANCE':'Saldo', 'BALANCE_FREQUENCY':'Frekuensi_Saldo', 'PURCHASES':'Pembelian', 
                        'ONEOFF_PURCHASES':'Pembelian_Oneoff', 'INSTALLMENTS_PURCHASES':'Pembelian_Angsuran',
                        'CASH_ADVANCE':'Penarikan_Tunai', 'PURCHASES_FREQUENCY':'Frekuensi_Pembelian',
                        'ONEOFF_PURCHASES_FREQUENCY':'Frekuensi_Pembelian_Oneoff', 
                        'PURCHASES_INSTALLMENTS_FREQUENCY':'Frekuensi_Pembelian_Angsuran', 
                        'CASH_ADVANCE_FREQUENCY':'Frekuensi_Penarikan_Tunai', 'CASH_ADVANCE_TRX':'Penarikan_Tunai_TRX', 
                        'PURCHASES_TRX':'Pembelian_TRX', 'CREDIT_LIMIT':'Batas_Kredit', 'PAYMENTS':'Pembayaran',
                        'MINIMUM_PAYMENTS':'Minimal_Pembayaran', 'PRC_FULL_PAYMENT':'Pembayaran_Full_PRC', 
                        'TENURE':'Jangka_Waktu'})

df_cc.head()
# Out:
#          Saldo  Frekuensi_Saldo  Pembelian  Pembelian_Oneoff  \
# 0    40.900749         0.818182      95.40              0.00
# 1  3202.467416         0.909091       0.00              0.00
# 2  2495.148862         1.000000     773.17            773.17
# 3  1666.670542         0.636364    1499.00           1499.00
# 4   817.714335         1.000000      16.00             16.00
#
#    Pembelian_Angsuran  Penarikan_Tunai  Frekuensi_Pembelian  \
# 0                95.4         0.000000             0.166667
# 1                 0.0      6442.945483             0.000000
# 2                 0.0         0.000000             1.000000
# 3                 0.0       205.788017             0.083333
# 4                 0.0         0.000000             0.083333
#
#    Frekuensi_Pembelian_Oneoff  Frekuensi_Pembelian_Angsuran  \
# 0                    0.000000                      0.083333
# 1                    0.000000                      0.000000
# 2                    1.000000                      0.000000
# 3                    0.083333                      0.000000
# 4                    0.083333                      0.000000
#
#    Frekuensi_Penarikan_Tunai  Penarikan_Tunai_TRX  Pembelian_TRX  \
# 0                   0.000000                    0              2
# 1                   0.250000                    4              0
# 2                   0.000000                    0             12
# 3                   0.083333                    1              1
# 4                   0.000000                    0              1
#
#    Batas_Kredit   Pembayaran  Minimal_Pembayaran  Pembayaran_Full_PRC  \
# 0        1000.0   201.802084          139.509787             0.000000
# 1        7000.0  4103.032597         1072.340217             0.222222
# 2        7500.0   622.066742          627.284787             0.000000
# 3        7500.0     0.000000          312.343947             0.000000
# 4        1200.0   678.334763          244.791237             0.000000
#
#    Jangka_Waktu
# 0            12
# 1            12
# 2            12
# 3            12
# 4            12

# %%
df_cc.columns
# Out:
# Index(['Saldo', 'Frekuensi_Saldo', 'Pembelian', 'Pembelian_Oneoff',
#        'Pembelian_Angsuran', 'Penarikan_Tunai', 'Frekuensi_Pembelian',
#        'Frekuensi_Pembelian_Oneoff', 'Frekuensi_Pembelian_Angsuran',
#        'Frekuensi_Penarikan_Tunai', 'Penarikan_Tunai_TRX', 'Pembelian_TRX',
#        'Batas_Kredit', 'Pembayaran', 'Minimal_Pembayaran',
#        'Pembayaran_Full_PRC', 'Jangka_Waktu'],
#       dtype='object')

# %%
# melihat jumlah nilai dari setiap atribut
for col in df_cc.columns:
    print(col, ' : ')
    print(df_cc[col].value_counts())
    print(" ")
    print(" ")
# Out:
# Saldo  :
# 0.000000       80
# 1100.941072     1
# 40.074484       1
# 2093.844656     1
# 179.765708      1
#                ..
# 1139.691004     1
# 3494.152843     1
# 2388.503738     1
# 2153.498372     1
# 510.233775      1
# Name: Saldo, Length: 8871, dtype: int64
#
#
# Frekuensi_Saldo  :
# 1.000000    6211
# 0.909091     410
# 0.818182     278
# 0.727273     223
# 0.545455     219
# 0.636364     209
# 0.454545     172
# 0.363636     170
# 0.272727     151
# 0.181818     146
# 0.000000      80
# 0.090909      67
# 0.833333      60
# 0.875000      57
# 0.900000      55
# 0.888889      53
# 0.857143      51
# 0.500000      40
# 0.666667      37
# 0.333333      22
# 0.777778      22
# 0.800000      20
# 0.571429      19
# 0.750000      17
# 0.714286      15
# 0.700000      13
# 0.625000      11
# 0.400000      10
# 0.555556      10
# 0.300000       9
# 0.200000       9
# 0.375000       9
# 0.125000       9
# 0.285714       8
# 0.100000       8
# 0.250000       8
# 0.444444       7
# 0.166667       7
# 0.142857       7
# 0.600000       6
# 0.111111       5
# 0.222222       5
# 0.428571       5
# Name: Frekuensi_Saldo, dtype: int64
#
#
# Pembelian  :
# 0.00       2044
# 45.65        27
# 150.00       16
# 60.00        16
# 100.00       13
#            ...
# 963.35        1
# 1260.13       1
# 203.60        1
# 35.97         1
# 169.66        1
# Name: Pembelian, Length: 6203, dtype: int64
#
#
# Pembelian_Oneoff  :
# 0.00       4302
# 45.65        46
# 50.00        17
# 200.00       15
# 60.00        13
#            ...
# 2814.23       1
# 2281.56       1
# 458.00        1
# 155.00        1
# 153.11        1
# Name: Pembelian_Oneoff, Length: 4014, dtype: int64
#
#
# Pembelian_Angsuran  :
# 0.00       3916
# 100.00       14
# 300.00       14
# 200.00       14
# 150.00       12
#            ...
# 1184.98       1
# 1673.59       1
# 1632.96       1
# 749.79        1
# 482.68        1
# Name: Pembelian_Angsuran, Length: 4452, dtype: int64
#
#
# Penarikan_Tunai  :
# 0.000000       4628
# 1286.356207       1
# 3816.470266       1
# 2495.298926       1
# 748.241727        1
#                ...
# 1282.314634       1
# 1384.954139       1
# 576.920984        1
# 1502.014320       1
# 1873.271885       1
# Name: Penarikan_Tunai, Length: 4323, dtype: int64
#
#
# Frekuensi_Pembelian  :
# 1.000000    2178
# 0.000000    2043
# 0.083333     677
# 0.916667     396
# 0.500000     395
# 0.166667     392
# 0.833333     373
# 0.333333     367
# 0.250000     345
# 0.583333     316
# 0.666667     310
# 0.750000     299
# 0.416667     289
# 0.090909      43
# 0.125000      32
# 0.909091      28
# 0.100000      27
# 0.142857      26
# 0.875000      26
# 0.857143      25
# 0.900000      24
# 0.818182      21
# 0.545455      20
# 0.454545      19
# 0.272727      19
# 0.200000      19
# 0.111111      18
# 0.888889      18
# 0.636364      17
# 0.181818      16
# 0.571429      16
# 0.727273      15
# 0.714286      13
# 0.300000      13
# 0.222222      12
# 0.700000      11
# 0.600000      11
# 0.375000      10
# 0.363636      10
# 0.428571       9
# 0.800000       9
# 0.400000       9
# 0.625000       8
# 0.285714       8
# 0.555556       7
# 0.777778       6
# 0.444444       5
# Name: Frekuensi_Pembelian, dtype: int64
#
#
# Frekuensi_Pembelian_Oneoff  :
# 0.000000    4302
# 0.083333    1104
# 0.166667     592
# 1.000000     481
# 0.250000     418
# 0.333333     355
# 0.416667     244
# 0.500000     235
# 0.583333     197
# 0.666667     167
# 0.916667     151
# 0.750000     142
# 0.833333     120
# 0.090909      56
# 0.125000      41
# 0.100000      39
# 0.142857      37
# 0.181818      34
# 0.200000      27
# 0.111111      26
# 0.454545      13
# 0.363636      13
# 0.222222      12
# 0.272727      12
# 0.571429      11
# 0.375000      11
# 0.300000      10
# 0.818182      10
# 0.285714       9
# 0.428571       8
# 0.545455       8
# 0.600000       7
# 0.636364       7
# 0.714286       7
# 0.727273       6
# 0.875000       6
# 0.400000       5
# 0.909091       4
# 0.444444       4
# 0.800000       4
# 0.700000       4
# 0.625000       3
# 0.888889       2
# 0.777778       2
# 0.555556       2
# 0.900000       1
# 0.857143       1
# Name: Frekuensi_Pembelian_Oneoff, dtype: int64
#
#
# Frekuensi_Pembelian_Angsuran  :
# 0.000000    3915
# 1.000000    1331
# 0.416667     388
# 0.916667     345
# 0.833333     311
# 0.500000     310
# 0.166667     305
# 0.666667     292
# 0.750000     291
# 0.083333     275
# 0.250000     255
# 0.333333     255
# 0.583333     225
# 0.857143      30
# 0.888889      28
# 0.875000      28
# 0.909091      25
# 0.714286      22
# 0.818182      21
# 0.454545      19
# 0.900000      19
# 0.800000      18
# 0.636364      16
# 0.181818      14
# 0.777778      13
# 0.272727      13
# 0.545455      13
# 0.090909      12
# 0.600000      12
# 0.363636      11
# 0.700000      11
# 0.300000      10
# 0.625000      10
# 0.571429      10
# 0.555556      10
# 0.200000       9
# 0.111111       9
# 0.727273       9
# 0.285714       9
# 0.400000       8
# 0.444444       8
# 0.428571       7
# 0.142857       6
# 0.375000       6
# 0.100000       6
# 0.222222       5
# 0.125000       5
# Name: Frekuensi_Pembelian_Angsuran, dtype: int64
#
#
# Frekuensi_Penarikan_Tunai  :
# 0.000000    4628
# 0.083333    1021
# 0.166667     759
# 0.250000     578
# 0.333333     439
# 0.416667     273
# 0.500000     215
# 0.583333     142
# 0.666667     125
# 0.090909      70
# 0.750000      63
# 0.142857      49
# 0.833333      48
# 0.125000      47
# 0.181818      42
# 0.100000      39
# 0.272727      38
# 0.285714      30
# 0.111111      29
# 0.916667      27
# 1.000000      25
# 0.300000      23
# 0.428571      21
# 0.200000      21
# 0.363636      20
# 0.222222      18
# 0.400000      15
# 0.444444      15
# 0.454545      14
# 0.571429      12
# 0.555556      12
# 0.375000      11
# 0.545455      10
# 0.600000       9
# 0.636364       8
# 0.727273       8
# 0.800000       6
# 0.625000       5
# 0.875000       5
# 0.857143       5
# 0.714286       4
# 0.777778       3
# 0.909091       3
# 0.888889       2
# 0.900000       2
# 0.818182       2
# 1.166667       2
# 1.500000       1
# 1.250000       1
# 1.142857       1
# 1.090909       1
# 1.100000       1
# 0.700000       1
# 1.125000       1
# Name: Frekuensi_Penarikan_Tunai, dtype: int64
#
#
# Penarikan_Tunai_TRX  :
# 0      4628
# 1       887
# 2       620
# 3       436
# 4       384
#        ...
# 69        1
# 93        1
# 46        1
# 110       1
# 71        1
# Name: Penarikan_Tunai_TRX, Length: 65, dtype: int64
#
#
# Pembelian_TRX  :
# 0      2044
# 1       667
# 12      570
# 2       379
# 6       352
#        ...
# 274       1
# 186       1
# 273       1
# 217       1
# 147       1
# Name: Pembelian_TRX, Length: 173, dtype: int64
#
#
# Batas_Kredit  :
# 3000.0    785
# 1500.0    722
# 1200.0    621
# 1000.0    614
# 2500.0    612
#          ...
# 50.0        1
# 9700.0      1
# 6850.0      1
# 5450.0      1
# 3650.0      1
# Name: Batas_Kredit, Length: 205, dtype: int64
#
#
# Pembayaran  :
# 0.000000       240
# 806.587482       1
# 836.812414       1
# 139.607827       1
# 107.242408       1
#               ...
# 3556.432004      1
# 2093.551911      1
# 3396.558042      1
# 227.392057       1
# 1656.726415      1
# Name: Pembayaran, Length: 8711, dtype: int64
#
#
# Minimal_Pembayaran  :
# 312.343947     314
# 299.351881       2
# 140.596138       1
# 111.691332       1
# 129.682608       1
#               ...
# 1227.773229      1
# 127.210691       1
# 6422.472544      1
# 471.940554       1
# 189.459157       1
# Name: Minimal_Pembayaran, Length: 8636, dtype: int64
#
#
# Pembayaran_Full_PRC  :
# 0.000000    5903
# 1.000000     488
# 0.083333     426
# 0.166667     166
# 0.250000     156
# 0.500000     156
# 0.090909     153
# 0.333333     134
# 0.100000      94
# 0.200000      83
# 0.666667      78
# 0.916667      77
# 0.181818      75
# 0.750000      68
# 0.833333      63
# 0.111111      61
# 0.142857      54
# 0.125000      52
# 0.416667      44
# 0.400000      42
# 0.300000      40
# 0.454545      36
# 0.272727      35
# 0.800000      33
# 0.363636      32
# 0.583333      31
# 0.600000      28
# 0.545455      27
# 0.636364      26
# 0.285714      24
# 0.727273      22
# 0.222222      20
# 0.714286      19
# 0.777778      19
# 0.909091      19
# 0.875000      18
# 0.818182      17
# 0.444444      17
# 0.900000      16
# 0.571429      14
# 0.428571      14
# 0.375000      13
# 0.857143      12
# 0.888889      12
# 0.700000      12
# 0.555556      12
# 0.625000       9
# Name: Pembayaran_Full_PRC, dtype: int64
#
#
# Jangka_Waktu  :
# 12    7584
# 11     365
# 10     236
# 6      204
# 8      196
# 7      190
# 9      175
# Name: Jangka_Waktu, dtype: int64

# %% [markdown]
# ## 5. EDA

# %%
# melihat statistik deskriptif pada data
df_cc.describe()
# Out:
#               Saldo  Frekuensi_Saldo     Pembelian  Pembelian_Oneoff  \
# count   8950.000000      8950.000000   8950.000000       8950.000000
# mean    1564.474828         0.877271   1003.204834        592.437371
# std     2081.531879         0.236904   2136.634782       1659.887917
# min        0.000000         0.000000      0.000000          0.000000
# 25%      128.281915         0.888889     39.635000          0.000000
# 50%      873.385231         1.000000    361.280000         38.000000
# 75%     2054.140036         1.000000   1110.130000        577.405000
# max    19043.138560         1.000000  49039.570000      40761.250000
#
#        Pembelian_Angsuran  Penarikan_Tunai  Frekuensi_Pembelian  \
# count         8950.000000      8950.000000          8950.000000
# mean           411.067645       978.871112             0.490351
# std            904.338115      2097.163877             0.401371
# min              0.000000         0.000000             0.000000
# 25%              0.000000         0.000000             0.083333
# 50%             89.000000         0.000000             0.500000
# 75%            468.637500      1113.821139             0.916667
# max          22500.000000     47137.211760             1.000000
#
#        Frekuensi_Pembelian_Oneoff  Frekuensi_Pembelian_Angsuran  \
# count                 8950.000000                   8950.000000
# mean                     0.202458                      0.364437
# std                      0.298336                      0.397448
# min                      0.000000                      0.000000
# 25%                      0.000000                      0.000000
# 50%                      0.083333                      0.166667
# 75%                      0.300000                      0.750000
# max                      1.000000                      1.000000
#
#        Frekuensi_Penarikan_Tunai  Penarikan_Tunai_TRX  Pembelian_TRX  \
# count                8950.000000          8950.000000    8950.000000
# mean                    0.135144             3.248827      14.709832
# std                     0.200121             6.824647      24.857649
# min                     0.000000             0.000000       0.000000
# 25%                     0.000000             0.000000       1.000000
# 50%                     0.000000             0.000000       7.000000
# 75%                     0.222222             4.000000      17.000000
# max                     1.500000           123.000000     358.000000
#
#        Batas_Kredit    Pembayaran  Minimal_Pembayaran  Pembayaran_Full_PRC  \
# count   8950.000000   8950.000000         8950.000000          8950.000000
# mean    4494.282473   1733.143852          844.906767             0.153715
# std     3638.646702   2895.063757         2332.792322             0.292499
# min       50.000000      0.000000            0.019163             0.000000
# 25%     1600.000000    383.276166          170.857654             0.000000
# 50%     3000.000000    856.901546          312.343947             0.000000
# 75%     6500.000000   1901.134317          788.713501             0.142857
# max    30000.000000  50721.483360        76406.207520             1.000000
#
#        Jangka_Waktu
# count   8950.000000
# mean      11.517318
# std        1.338331
# min        6.000000
# 25%       12.000000
# 50%       12.000000
# 75%       12.000000
# max       12.000000

# %%
# melihat nilai minimum pada setiap data

minimum = df_cc.min()
minimum
# Out:
# Saldo                            0.000000
# Frekuensi_Saldo                  0.000000
# Pembelian                        0.000000
# Pembelian_Oneoff                 0.000000
# Pembelian_Angsuran               0.000000
# Penarikan_Tunai                  0.000000
# Frekuensi_Pembelian              0.000000
# Frekuensi_Pembelian_Oneoff       0.000000
# Frekuensi_Pembelian_Angsuran     0.000000
# Frekuensi_Penarikan_Tunai        0.000000
# Penarikan_Tunai_TRX              0.000000
# Pembelian_TRX                    0.000000
# Batas_Kredit                    50.000000
# Pembayaran                       0.000000
# Minimal_Pembayaran               0.019163
# Pembayaran_Full_PRC              0.000000
# Jangka_Waktu                     6.000000
# dtype: float64

# %%
# melihat nilai maximum pada setiap data

maximum = df_cc.max()
maximum
# Out:
# Saldo                           19043.13856
# Frekuensi_Saldo                     1.00000
# Pembelian                       49039.57000
# Pembelian_Oneoff                40761.25000
# Pembelian_Angsuran              22500.00000
# Penarikan_Tunai                 47137.21176
# Frekuensi_Pembelian                 1.00000
# Frekuensi_Pembelian_Oneoff          1.00000
# Frekuensi_Pembelian_Angsuran        1.00000
# Frekuensi_Penarikan_Tunai           1.50000
# Penarikan_Tunai_TRX               123.00000
# Pembelian_TRX                     358.00000
# Batas_Kredit                    30000.00000
# Pembayaran                      50721.48336
# Minimal_Pembayaran              76406.20752
# Pembayaran_Full_PRC                 1.00000
# Jangka_Waktu                       12.00000
# dtype: float64

# %% [markdown]
# #### Melihat pengguna kartu kredit berdasarkan jangka waktu yang diambil

# %%
df_cc['Jangka_Waktu'].value_counts().plot.bar()
plt.title('Jumlah Pengguna berdasarkan Jangka Waktu Kartu Kredit')
plt.ylabel('Pengguna')
plt.xlabel('Jangka Waktu')
plt.show()

# %% [markdown]
# Dapat dilihat dari visualisasi data diatas bahwa lebih banyak pengguna yang mengambil jangka waktu kredit dalam waktu 12 bulan dengan jumlah pengguna diatas 7000 orang.

# %% [markdown]
# #### Melihat batas kredit berdasarkan jangka waktu kredit

# %%
df_kredit = df_cc.pivot_table(
    index='Jangka_Waktu',
    values='Batas_Kredit',
    aggfunc='mean'
)
df_kredit
# Out:
#               Batas_Kredit
# Jangka_Waktu
# 6              3002.549020
# 7              2567.631579
# 8              2973.724490
# 9              2977.904762
# 10             3871.610169
# 11             4141.232877
# 12             4693.331329

# %%
# visualisasi batas kredit berdasarkan jangka waktu

df_kredit.plot(kind='bar', figsize=(5, 5), legend=None)
plt.title('Rata-rata batas kredit berdasarkan jangka waktu')
plt.ylabel('Batas Kredit')
plt.xlabel('Jangka Waktu')
plt.show()

# %% [markdown]
# Dari data diatas dapat diketahui bahwa pengguna yang mengambil layanan kartu kredit dengan jangka waktu lebih lama akan mendapatkan batas kredit yang lebih besar.

# %%
# Histogram data
df_cc.hist(figsize=(10,10))

plt.show()

# %%
# melihat korelasi data
df_cc.corr()
# Out:
#                                  Saldo  Frekuensi_Saldo  Pembelian  \
# Saldo                         1.000000         0.322412   0.181261
# Frekuensi_Saldo               0.322412         1.000000   0.133674
# Pembelian                     0.181261         0.133674   1.000000
# Pembelian_Oneoff              0.164350         0.104323   0.916845
# Pembelian_Angsuran            0.126469         0.124292   0.679896
# Penarikan_Tunai               0.496692         0.099388  -0.051474
# Frekuensi_Pembelian          -0.077944         0.229715   0.393017
# Frekuensi_Pembelian_Oneoff    0.073166         0.202415   0.498430
# Frekuensi_Pembelian_Angsuran -0.063186         0.176079   0.315567
# Frekuensi_Penarikan_Tunai     0.449218         0.191873  -0.120143
# Penarikan_Tunai_TRX           0.385152         0.141555  -0.067175
# Pembelian_TRX                 0.154338         0.189626   0.689561
# Batas_Kredit                  0.531296         0.095931   0.356977
# Pembayaran                    0.322802         0.065008   0.603264
# Minimal_Pembayaran            0.397920         0.131181   0.095789
# Pembayaran_Full_PRC          -0.318959        -0.095082   0.180379
# Jangka_Waktu                  0.072692         0.119776   0.086288
#
#                               Pembelian_Oneoff  Pembelian_Angsuran  \
# Saldo                                 0.164350            0.126469
# Frekuensi_Saldo                       0.104323            0.124292
# Pembelian                             0.916845            0.679896
# Pembelian_Oneoff                      1.000000            0.330622
# Pembelian_Angsuran                    0.330622            1.000000
# Penarikan_Tunai                      -0.031326           -0.064244
# Frekuensi_Pembelian                   0.264937            0.442418
# Frekuensi_Pembelian_Oneoff            0.524891            0.214042
# Frekuensi_Pembelian_Angsuran          0.127729            0.511351
# Frekuensi_Penarikan_Tunai            -0.082628           -0.132318
# Penarikan_Tunai_TRX                  -0.046212           -0.073999
# Pembelian_TRX                         0.545523            0.628108
# Batas_Kredit                          0.319735            0.256515
# Pembayaran                            0.567292            0.384084
# Minimal_Pembayaran                    0.050256            0.134019
# Pembayaran_Full_PRC                   0.132763            0.182569
# Jangka_Waktu                          0.064150            0.086143
#
#                               Penarikan_Tunai  Frekuensi_Pembelian  \
# Saldo                                0.496692            -0.077944
# Frekuensi_Saldo                      0.099388             0.229715
# Pembelian                           -0.051474             0.393017
# Pembelian_Oneoff                    -0.031326             0.264937
# Pembelian_Angsuran                  -0.064244             0.442418
# Penarikan_Tunai                      1.000000            -0.215507
# Frekuensi_Pembelian                 -0.215507             1.000000
# Frekuensi_Pembelian_Oneoff          -0.086754             0.501343
# Frekuensi_Pembelian_Angsuran        -0.177070             0.862934
# Frekuensi_Penarikan_Tunai            0.628522            -0.308478
# Penarikan_Tunai_TRX                  0.656498            -0.203478
# Pembelian_TRX                       -0.075850             0.568430
# Batas_Kredit                         0.303997             0.119833
# Pembayaran                           0.453238             0.103464
# Minimal_Pembayaran                   0.140747             0.006154
# Pembayaran_Full_PRC                 -0.152935             0.305802
# Jangka_Waktu                        -0.068312             0.061506
#
#                               Frekuensi_Pembelian_Oneoff  \
# Saldo                                           0.073166
# Frekuensi_Saldo                                 0.202415
# Pembelian                                       0.498430
# Pembelian_Oneoff                                0.524891
# Pembelian_Angsuran                              0.214042
# Penarikan_Tunai                                -0.086754
# Frekuensi_Pembelian                             0.501343
# Frekuensi_Pembelian_Oneoff                      1.000000
# Frekuensi_Pembelian_Angsuran                    0.142329
# Frekuensi_Penarikan_Tunai                      -0.111716
# Penarikan_Tunai_TRX                            -0.069088
# Pembelian_TRX                                   0.544869
# Batas_Kredit                                    0.295059
# Pembayaran                                      0.243537
# Minimal_Pembayaran                             -0.027311
# Pembayaran_Full_PRC                             0.157531
# Jangka_Waktu                                    0.082466
#
#                               Frekuensi_Pembelian_Angsuran  \
# Saldo                                            -0.063186
# Frekuensi_Saldo                                   0.176079
# Pembelian                                         0.315567
# Pembelian_Oneoff                                  0.127729
# Pembelian_Angsuran                                0.511351
# Penarikan_Tunai                                  -0.177070
# Frekuensi_Pembelian                               0.862934
# Frekuensi_Pembelian_Oneoff                        0.142329
# Frekuensi_Pembelian_Angsuran                      1.000000
# Frekuensi_Penarikan_Tunai                        -0.262958
# Penarikan_Tunai_TRX                              -0.169207
# Pembelian_TRX                                     0.529975
# Batas_Kredit                                      0.060794
# Pembayaran                                        0.085551
# Minimal_Pembayaran                                0.032055
# Pembayaran_Full_PRC                               0.250087
# Jangka_Waktu                                      0.073275
#
#                               Frekuensi_Penarikan_Tunai  Penarikan_Tunai_TRX  \
# Saldo                                          0.449218             0.385152
# Frekuensi_Saldo                                0.191873             0.141555
# Pembelian                                     -0.120143            -0.067175
# Pembelian_Oneoff                              -0.082628            -0.046212
# Pembelian_Angsuran                            -0.132318            -0.073999
# Penarikan_Tunai                                0.628522             0.656498
# Frekuensi_Pembelian                           -0.308478            -0.203478
# Frekuensi_Pembelian_Oneoff                    -0.111716            -0.069088
# Frekuensi_Pembelian_Angsuran                  -0.262958            -0.169207
# Frekuensi_Penarikan_Tunai                      1.000000             0.799561
# Penarikan_Tunai_TRX                            0.799561             1.000000
# Pembelian_TRX                                 -0.131168            -0.066157
# Batas_Kredit                                   0.132608             0.149713
# Pembayaran                                     0.183192             0.255278
# Minimal_Pembayaran                             0.100616             0.111251
# Pembayaran_Full_PRC                           -0.249773            -0.169784
# Jangka_Waktu                                  -0.133372            -0.043421
#
#                               Pembelian_TRX  Batas_Kredit  Pembayaran  \
# Saldo                              0.154338      0.531296    0.322802
# Frekuensi_Saldo                    0.189626      0.095931    0.065008
# Pembelian                          0.689561      0.356977    0.603264
# Pembelian_Oneoff                   0.545523      0.319735    0.567292
# Pembelian_Angsuran                 0.628108      0.256515    0.384084
# Penarikan_Tunai                   -0.075850      0.303997    0.453238
# Frekuensi_Pembelian                0.568430      0.119833    0.103464
# Frekuensi_Pembelian_Oneoff         0.544869      0.295059    0.243537
# Frekuensi_Pembelian_Angsuran       0.529975      0.060794    0.085551
# Frekuensi_Penarikan_Tunai         -0.131168      0.132608    0.183192
# Penarikan_Tunai_TRX               -0.066157      0.149713    0.255278
# Pembelian_TRX                      1.000000      0.272902    0.370832
# Batas_Kredit                       0.272902      1.000000    0.421876
# Pembayaran                         0.370832      0.421876    1.000000
# Minimal_Pembayaran                 0.098722      0.126765    0.128960
# Pembayaran_Full_PRC                0.162066      0.055695    0.112138
# Jangka_Waktu                       0.121874      0.139222    0.106136
#
#                               Minimal_Pembayaran  Pembayaran_Full_PRC  \
# Saldo                                   0.397920            -0.318959
# Frekuensi_Saldo                         0.131181            -0.095082
# Pembelian                               0.095789             0.180379
# Pembelian_Oneoff                        0.050256             0.132763
# Pembelian_Angsuran                      0.134019             0.182569
# Penarikan_Tunai                         0.140747            -0.152935
# Frekuensi_Pembelian                     0.006154             0.305802
# Frekuensi_Pembelian_Oneoff             -0.027311             0.157531
# Frekuensi_Pembelian_Angsuran            0.032055             0.250087
# Frekuensi_Penarikan_Tunai               0.100616            -0.249773
# Penarikan_Tunai_TRX                     0.111251            -0.169784
# Pembelian_TRX                           0.098722             0.162066
# Batas_Kredit                            0.126765             0.055695
# Pembayaran                              0.128960             0.112138
# Minimal_Pembayaran                      1.000000            -0.135194
# Pembayaran_Full_PRC                    -0.135194             1.000000
# Jangka_Waktu                            0.060006            -0.016486
#
#                               Jangka_Waktu
# Saldo                             0.072692
# Frekuensi_Saldo                   0.119776
# Pembelian                         0.086288
# Pembelian_Oneoff                  0.064150
# Pembelian_Angsuran                0.086143
# Penarikan_Tunai                  -0.068312
# Frekuensi_Pembelian               0.061506
# Frekuensi_Pembelian_Oneoff        0.082466
# Frekuensi_Pembelian_Angsuran      0.073275
# Frekuensi_Penarikan_Tunai        -0.133372
# Penarikan_Tunai_TRX              -0.043421
# Pembelian_TRX                     0.121874
# Batas_Kredit                      0.139222
# Pembayaran                        0.106136
# Minimal_Pembayaran                0.060006
# Pembayaran_Full_PRC              -0.016486
# Jangka_Waktu                      1.000000

# %%
# melihat korelasi antar data dalam heatmap
plt.figure(figsize=(16, 9))
sns.heatmap(df_cc.corr(), annot=True)
plt.show()

# %% [markdown]
# Dari heatmap diatas dapat diketahui korelasi yang cukup tinggi untuk setiap kolom, yaitu :
# - Pembelian dengan Pembelian Oneoff dengan nilai korelasi 0.92
# - Frekuensi Pembelian dengan Frekuensi Pembelian Angsuran dengan nilai korelasi 0.86

# %% [markdown]
# ## 6. Data Preprocessing

# %%
# Standardize data
scaler = StandardScaler() 
data = scaler.fit_transform(df_cc)

# %%
data_new = pd.DataFrame(data, columns=df_cc.columns)
data_new.head()
# Out:
#       Saldo  Frekuensi_Saldo  Pembelian  Pembelian_Oneoff  Pembelian_Angsuran  \
# 0 -0.731989        -0.249434  -0.424900         -0.356934           -0.349079
# 1  0.786961         0.134325  -0.469552         -0.356934           -0.454576
# 2  0.447135         0.518084  -0.107668          0.108889           -0.454576
# 3  0.049099        -1.016953   0.232058          0.546189           -0.454576
# 4 -0.358775         0.518084  -0.462063         -0.347294           -0.454576
#
#    Penarikan_Tunai  Frekuensi_Pembelian  Frekuensi_Pembelian_Oneoff  \
# 0        -0.466786            -0.806490                   -0.678661
# 1         2.605605            -1.221758                   -0.678661
# 2        -0.466786             1.269843                    2.673451
# 3        -0.368653            -1.014125                   -0.399319
# 4        -0.466786            -1.014125                   -0.399319
#
#    Frekuensi_Pembelian_Angsuran  Frekuensi_Penarikan_Tunai  \
# 0                     -0.707313                  -0.675349
# 1                     -0.916995                   0.573963
# 2                     -0.916995                  -0.675349
# 3                     -0.916995                  -0.258913
# 4                     -0.916995                  -0.675349
#
#    Penarikan_Tunai_TRX  Pembelian_TRX  Batas_Kredit  Pembayaran  \
# 0            -0.476070      -0.511333     -0.960378   -0.528979
# 1             0.110074      -0.591796      0.688678    0.818642
# 2            -0.476070      -0.109020      0.826100   -0.383805
# 3            -0.329534      -0.551565      0.826100   -0.598688
# 4            -0.476070      -0.551565     -0.905410   -0.364368
#
#    Minimal_Pembayaran  Pembayaran_Full_PRC  Jangka_Waktu
# 0           -0.302400            -0.525551       0.36068
# 1            0.097500             0.234227       0.36068
# 2           -0.093293            -0.525551       0.36068
# 3           -0.228307            -0.525551       0.36068
# 4           -0.257266            -0.525551       0.36068

# %% [markdown]
# ## 7. Model Definition

# %% [markdown]
# #### a. PCA (Principal Component Analysis)

# %%
pca = PCA()
pca
# Out:
# PCA()

# %% [markdown]
# #### b. K-Means Clustering

# %%
Kmean = KMeans(n_clusters=2)
Kmean
# Out:
# KMeans(n_clusters=2)

# %% [markdown]
# ## 8. Model Training

# %% [markdown]
# #### a. PCA

# %%
principalComponents = pca.fit_transform(data_new)

# %% [markdown]
# #### b. K-Means

# %%
KMeansCluster = Kmean.fit(data_new)

# %% [markdown]
# ### 9. Model Evalution

# %% [markdown]
# #### a. PCA

# %%
pca_cc = PCA(n_components=4)
principalcomponents = pca_cc.fit_transform(data_new)

# %%
principal_cc = pd.DataFrame(data=principalcomponents, columns=['PC_1','PC_2','PC_3','PC_4'])

# %%
principal_cc.tail()
# Out:
#           PC_1      PC_2      PC_3      PC_4
# 8945 -0.362572 -2.013435 -0.975730 -2.742307
# 8946 -0.580810 -1.675662 -1.222453 -1.980447
# 8947 -0.928986 -1.808047 -0.458359 -2.296195
# 8948 -2.337845 -0.653610  0.982760 -1.847626
# 8949 -0.558026 -0.400647  1.033724 -1.940097

# %%
print('Explained variation per principal component :{}'.format(pca_cc.explained_variance_ratio_))
# Out:
# Explained variation per principal component :[0.27297671 0.2031378  0.08813182 0.07479524]

# %%
np.cumsum(pca_cc.explained_variance_ratio_)
# Out:
# array([0.27297671, 0.47611451, 0.56424633, 0.63904157])

# %% [markdown]
# Dapat dilihat dari keluaran diatas bahwa :
# - PC 1 menampung 27% informasi
# - PC 2 menampung 20% informasi
# - PC 3 menampung 8% informasi
# - PC 4 menampung 7% informasi
#
# hal lain yang perlu diperhatikan adalah 38% informasi hilang karena dari 17 dimensi diproyeksikan menjadi 4 dimensi

# %% [markdown]
# #### b. K-Means Clustering

# %% [markdown]
# #### Elbow Method

# %%
wcss = []

for i in range(1, 20):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', max_iter = 300, n_init = 10, random_state = 0)
    kmeans.fit(principal_cc)
    wcss.append(kmeans.inertia_)
    
plt.plot(range(1, 20), wcss, marker='o')
plt.title('The elbow method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS') #within cluster sum of squares
plt.show()

# %% [markdown]
# Dapat dilihat menggunakan elbow method bahwa jumlah cluster yang optimum antara 5 sampai 7. Maka, akan dicoba menggunakan 5 cluster

# %%
scaler = StandardScaler() 
data = scaler.fit_transform(principal_cc)

# %%
pd.DataFrame(principal_cc).describe()
# Out:
#                PC_1          PC_2          PC_3          PC_4
# count  8.950000e+03  8.950000e+03  8.950000e+03  8.950000e+03
# mean   9.242638e-16  8.019035e-16 -5.083457e-17 -1.935882e-16
# std    2.154327e+00  1.858421e+00  1.224095e+00  1.127680e+00
# min   -2.781003e+00 -2.679952e+00 -9.886715e+00 -1.112367e+01
# 25%   -1.484081e+00 -1.264115e+00 -7.712438e-01 -6.250642e-01
# 50%   -4.554402e-01 -4.860406e-01  5.070197e-02  1.343983e-01
# 75%    7.621886e-01  7.387883e-01  5.595894e-01  7.046295e-01
# max    2.960305e+01  2.537036e+01  1.692524e+01  1.390419e+01

# %%
kmeans = KMeans(n_clusters=5, init='k-means++')
kmeans.fit(principal_cc)
pred = kmeans.predict(principal_cc)

# %%
frame = pd.DataFrame(principal_cc)
frame['cluster'] = pred
frame['cluster'].value_counts()
# Out:
# 0    3928
# 1    3052
# 4    1202
# 2     738
# 3      30
# Name: cluster, dtype: int64

# %%
# Membuat visualisasi klaster
plt.figure(figsize=(10,10))
ax = sns.scatterplot(x="PC_1", y="PC_2", hue = "cluster", data = frame,
                     palette = 'Dark2')
plt.show()

# %%
df_frame = pd.concat([df_cc, frame.iloc[:, 4]], axis='columns')

# %%
plt.figure(figsize=(15,7))
sns.scatterplot(data=df_frame, x='Pembelian', y='Pembayaran', hue = 'cluster', s=25, palette="Set2")
# Out:
# <AxesSubplot:xlabel='Pembelian', ylabel='Pembayaran'>

# %%
plt.figure(figsize=(15,7))
sns.scatterplot(data=df_frame, x='Pembelian', y='Saldo', hue = 'cluster', s=25, palette="Set2")
# Out:
# <AxesSubplot:xlabel='Pembelian', ylabel='Saldo'>

# %%
df_frame.shape
# Out:
# (8950, 18)

# %%
various_df = df_frame.iloc[:, [0,2,3,4,5,13,17]]

# %%
various_df.groupby('cluster').mean().plot.bar(figsize=(15, 5))
plt.show()

# %%
df_frame_without_3 = df_frame.copy()

# %%
df_frame_without_3 = df_frame_without_3[df_frame_without_3['cluster'].isin([0,1,2,4])]

# %%
various_df_without_3 = df_frame_without_3.iloc[:, [0,2,3,4,5,13,17]]

# %%
various_df_without_3.groupby('cluster').mean().plot.bar(figsize=(15, 5))
plt.show()
